# %%
import requests

# %%
import bs4

# %%
result = requests.get("http://www.example.com")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
soup = bs4.BeautifulSoup(result.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
site_para = soup.select('p')

# %%
site_para[0].getText()
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %%
## Grabbing all elements of a class

# %%
res = requests.get('https://en.wikipedia.org/wiki/Shaquille_O%27Neal')

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
list_scrape = soup.select('.infobox-data')

# %%
 for item in list_scrape:
        print(item.getText())
# Out:
#  (1972-03-06) March 6, 1972 (age 51)Newark, New Jersey, U.S.
# 7 ft 1 in (216 cm)[1]
# 325 lb (147 kg)[1]
#
# Fulda American (Fulda, Germany)
# Robert G. Cole (San Antonio, Texas)
#
# LSU (1989–1992)
# 1992: 1st  round, 1st overall pick
# 1992–2011
# Center
# 32, 34, 33, 36
# Orlando Magic
# Los Angeles Lakers
# Miami Heat
# Phoenix Suns
# Cleveland Cavaliers
# Boston Celtics
# 28,596 (23.7 ppg)
# 13,099 (10.9 rpg)
# 2,732 (2.3 bpg)
# Hip hop, electronic dance music
# Rapper, DJ
# 1993–2001; 2017–present
# Jive, Interscope, A&M, Trauma, Monstercat

# %%
## Grabbing an image

# %%
res = requests.get('https://en.wikipedia.org/wiki/Shaquille_O%27Neal')

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
soup.select('.mw-file-element')[0]
# Out:
# <img alt="Page semi-protected" class="mw-file-element" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>

# %%
headshot = soup.select('.mw-file-element')[9]

# %%
headshot
# Out:
# <img class="mw-file-element" data-file-height="3146" data-file-width="1227" decoding="async" height="333" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Shaq1_2000finals3.tif/lossy-page1-130px-Shaq1_2000finals3.tif.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Shaq1_2000finals3.tif/lossy-page1-195px-Shaq1_2000finals3.tif.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Shaq1_2000finals3.tif/lossy-page1-260px-Shaq1_2000finals3.tif.jpg 2x" width="130"/>

# %%
headshot['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Shaq1_2000finals3.tif/lossy-page1-130px-Shaq1_2000finals3.tif.jpg'

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Shaq1_2000finals3.tif/lossy-page1-130px-Shaq1_2000finals3.tif.jpg">

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png">

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Shaq1_2000finals3.tif/lossy-page1-130px-Shaq1_2000finals3.tif.jpg')

# %%
image_link.content
# Out:
# b'\xff\xd8\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00@gTRC\x00\x00\x01\xcc\x00\x00\x00@bTRC\x00\x00\x01\xcc\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x03c2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x
# ...

# %%
f = open('my_comp_image.jpg', 'wb')

# %%
f.write(image_link.content)
# Out:
# 17420

# %%
f.close()
